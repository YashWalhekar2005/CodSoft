# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
file=pd.read_csv("creditcard.csv")

# %%
file.head(10)
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0     0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1     0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2     1 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3     1 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4     2 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
# 5     2 -0.425966  0.960523  1.141109 -0.168252  0.420987 -0.029728  0.476201
# 6     4  1.229658  0.141004  0.045371  1.202613  0.191881  0.272708 -0.005159
# 7     7 -0.644269  1.417964  1.074380 -0.492199  0.948934  0.428118  1.120631
# 8     7 -0.894286  0.286157 -0.113192 -0.271526  2.669599  3.721818  0.370145
# 9     9 -0.338262  1.119593  1.044367 -0.222187  0.499361 -0.246761  0.651583
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
# 5  0.260314 -0.568671  ... -0.208254 -0.559825 -0.026398 -0.371427 -0.232794
# 6  0.081213  0.464960  ... -0.167716 -0.270710 -0.154104 -0.780055  0.750137
# 7 -3.807864  0.615375  ...  1.943465 -1.015455  0.057504 -0.649709 -0.415267
# 8  0.851084 -0.392048  ... -0.073425 -0.268092 -0.204233  1.011592  0.373205
# 9  0.069539 -0.736727  ... -0.246914 -0.633753 -0.120794 -0.385050 -0.069733
#
#         V26       V27       V28  Amount  Class
# 0 -0.189115  0.133558 -0.021053  149.62    0.0
# 1  0.125895 -0.008983  0.014724    2.69    0.0
# 2 -0.139097 -0.055353 -0.059752  378.66    0.0
# 3 -0.221929  0.062723  0.061458  123.50    0.0
# 4  0.502292  0.219422  0.215153   69.99    0.0
# 5  0.105915  0.253844  0.081080    3.67    0.0
# 6 -0.257237  0.034507  0.005168    4.99    0.0
# 7 -0.051634 -1.206921 -1.085339   40.80    0.0
# 8 -0.384157  0.011747  0.142404   93.20    0.0
# 9  0.094199  0.246219  0.083076    3.68    0.0
#
# [10 rows x 31 columns]

# %%
file.describe()
# Out:
#               Time           V1           V2           V3           V4  \
# count  1986.000000  1986.000000  1986.000000  1986.000000  1986.000000
# mean    761.035750    -0.284195     0.266886     0.848005     0.151216
# std     451.034025     1.353508     1.142026     1.012645     1.264932
# min       0.000000   -11.140706   -12.114213   -12.389545    -4.657545
# 25%     366.000000    -1.045512    -0.204111     0.280517    -0.670513
# 50%     750.000000    -0.437621     0.314294     0.864505     0.190698
# 75%    1161.000000     1.095047     0.926126     1.486942     1.002546
# max    1526.000000     1.685314     6.118940     4.017561     6.013346
#
#                 V5           V6           V7           V8           V9  ...  \
# count  1986.000000  1986.000000  1986.000000  1986.000000  1986.000000  ...
# mean     -0.077457     0.050205     0.138347    -0.058795     0.012145  ...
# std       1.272512     1.274204     1.140750     0.966493     0.900828  ...
# min     -32.092129    -3.498447    -4.925568   -12.258158    -3.110515  ...
# 25%      -0.576269    -0.691393    -0.286991    -0.172322    -0.479310  ...
# 50%      -0.154843    -0.198063     0.117535     0.037598    -0.034097  ...
# 75%       0.376901     0.389714     0.569262     0.279513     0.449706  ...
# max       7.672544    21.393069    34.303177     3.877662     6.450992  ...
#
#                V21          V22          V23          V24          V25  \
# count  1985.000000  1985.000000  1985.000000  1985.000000  1985.000000
# mean     -0.011611    -0.144319    -0.043045     0.013864     0.108372
# std       0.653200     0.588201     0.352890     0.601370     0.407874
# min      -4.709977    -2.776923    -4.020300    -2.162523    -1.577384
# 25%      -0.226941    -0.547474    -0.181176    -0.350802    -0.151028
# 50%      -0.087329    -0.152603    -0.057041     0.093137     0.131713
# 75%       0.083530     0.252698     0.064859     0.428755     0.383339
# max       6.765928     1.957759     4.095021     1.215279     1.629684
#
#                V26          V27          V28       Amount        Class
# count  1985.000000  1985.000000  1985.000000  1985.000000  1985.000000
# mean      0.049408     0.027197    -0.002018    68.602469     0.001008
# std       0.454251     0.369485     0.272864   241.677019     0.031734
# min      -1.243924    -5.336289    -2.738566     0.000000     0.000000
# 25%      -0.281097    -0.049467    -0.021053     4.950000     0.000000
# 50%       0.036992     0.023011     0.022722    15.090000     0.000000
# 75%       0.303731     0.140481     0.090920    63.650000     0.000000
# max       3.463246     3.852046     4.157934  7712.430000     1.000000
#
# [8 rows x 31 columns]

# %%
file.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       1
# V15       1
# V16       1
# V17       1
# V18       1
# V19       1
# V20       1
# V21       1
# V22       1
# V23       1
# V24       1
# V25       1
# V26       1
# V27       1
# V28       1
# Amount    1
# Class     1
# dtype: int64

# %%
file['Class'].value_counts()
# Out:
# 0.0    1983
# 1.0       2
# Name: Class, dtype: int64

# %%
normal=file[file.Class==0]

# %%
fraud=file[file.Class==1]

# %%
print(normal.shape)
# Out:
# (1983, 31)

# %%
print(normal.shape)
# Out:
# (1983, 31)

# %%
normal.Amount.describe()
# Out:
# count    1983.000000
# mean       68.404892
# std       241.572682
# min         0.000000
# 25%         4.950000
# 50%        15.090000
# 75%        63.285000
# max      7712.430000
# Name: Amount, dtype: float64

# %%
fraud.Amount.describe()
# Out:
# count      2.000000
# mean     264.500000
# std      374.059487
# min        0.000000
# 25%      132.250000
# 50%      264.500000
# 75%      396.750000
# max      529.000000
# Name: Amount, dtype: float64

# %%
file.groupby('Class').mean()
# Out:
#              Time        V1        V2        V3        V4        V5        V6  \
# Class
# 0.0    760.974786 -0.281494  0.267200  0.848906  0.146804 -0.077904  0.051713
# 1.0    439.000000 -2.677884 -0.602658 -0.260694  3.143275  0.418809 -1.245684
#
#              V7        V8        V9  ...       V20       V21       V22  \
# Class                                ...
# 0.0    0.139533 -0.059771  0.014492  ...  0.056618 -0.012217 -0.144666
# 1.0   -1.105907  0.661932 -1.520521  ...  1.114625  0.589464  0.200214
#
#             V23       V24       V25       V26       V27       V28      Amount
# Class
# 0.0   -0.043548  0.013865  0.108318  0.049441  0.027220 -0.001966   68.404892
# 1.0    0.455377  0.013198  0.162159  0.016239  0.004186 -0.053756  264.500000
#
# [2 rows x 30 columns]

# %%
normal_sample=normal.sample(n=492)

# %%
new_file=pd.concat([normal_sample,fraud],axis=0)

# %%
new_file.head(10)
# Out:
#       Time        V1        V2        V3        V4        V5        V6  \
# 1241   957 -0.922509  0.480399  2.091886  1.646377 -0.512384  0.229682
# 533    402 -0.160626 -0.064459  2.531072 -1.328268 -0.970430  0.185030
# 930    705 -0.590526  0.756030  1.620537 -0.109645  0.062481 -0.310831
# 967    734  1.215176  0.337917  0.287224  0.638964 -0.148269 -0.593767
# 83      53 -1.198968 -1.474100  1.840326 -4.515824  0.327567 -0.174469
# 1778  1379 -1.311838  0.325574  1.610455  1.603615  0.515583 -0.740860
# 1010   762 -0.253289  0.585177  0.829882 -0.839618 -0.076722 -1.030359
# 19      15  1.492936 -1.029346  0.454795 -1.438026 -1.555434 -0.720961
# 1595  1242 -1.934514  0.398684 -0.676379 -2.270048 -0.761439 -0.591461
# 1083   833 -1.187166  0.909008  1.536579 -1.473195 -0.259056 -0.474062
#
#             V7        V8        V9  ...       V21       V22       V23  \
# 1241  0.630477 -0.591026  0.705361  ...  0.113923  0.906466 -0.295780
# 533  -0.380184  0.078119  1.775956  ...  0.262124  1.340696 -0.253860
# 930   0.386568  0.279559 -0.491829  ... -0.138553 -0.430450  0.059278
# 967   0.034927 -0.087724 -0.031720  ... -0.255929 -0.682293  0.154842
# 83    0.959726 -1.026456  1.700435  ... -0.453169  0.334614 -0.364541
# 1778  0.019448  0.067418  0.046210  ... -0.036956  0.232325 -0.189235
# 1010  0.588550 -0.238624 -2.274743  ...  0.370128  0.988195 -0.297364
# 19   -1.080664 -0.053127 -1.978682  ... -0.177650 -0.175074  0.040002
# 1595  0.717055  0.778131  0.259545  ...  0.119474  0.422229  0.277076
# 1083  0.326941  0.320549  0.304973  ... -0.071627 -0.083652 -0.001690
#
#            V24       V25       V26       V27       V28  Amount  Class
# 1241  0.442751 -0.324682 -0.153798 -0.826676 -0.028785   84.95    0.0
# 533   0.178601 -0.491121  0.244972  0.074829 -0.069924    0.01    0.0
# 930   0.172907 -0.357478  0.074625  0.266242  0.109266    4.99    0.0
# 967   0.044834  0.157157  0.122874 -0.003804  0.028114    0.89    0.0
# 83   -0.310186 -0.302599 -1.243924 -1.123457 -0.734351   89.17    0.0
# 1778  0.613825 -0.171097 -0.261470  0.194658  0.294471    4.49    0.0
# 1010  0.530663  0.204413 -0.014838  0.094524  0.120878   29.99    0.0
# 19    0.295814  0.332931 -0.220385  0.022298  0.007602    5.00    0.0
# 1595 -0.259721  0.024995 -0.080820  0.399133 -0.133506  160.00    0.0
# 1083  0.213348 -0.419059  0.733156  0.480212  0.285813    8.00    0.0
#
# [10 rows x 31 columns]

# %%
new_file['Class'].value_counts()
# Out:
# 0.0    492
# 1.0      2
# Name: Class, dtype: int64

# %%
new_file.groupby('Class').mean()
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# Class
# 0.0    773.45122 -0.332067  0.200991  0.842512  0.030018 -0.084557  0.013852
# 1.0    439.00000 -2.677884 -0.602658 -0.260694  3.143275  0.418809 -1.245684
#
#              V7        V8        V9  ...       V20       V21       V22  \
# Class                                ...
# 0.0    0.148527 -0.033469  0.066728  ...  0.055851 -0.031792 -0.118790
# 1.0   -1.105907  0.661932 -1.520521  ...  1.114625  0.589464  0.200214
#
#             V23       V24       V25       V26       V27       V28      Amount
# Class
# 0.0   -0.039500  0.053448  0.110701  0.037314  0.008645 -0.017495   73.701951
# 1.0    0.455377  0.013198  0.162159  0.016239  0.004186 -0.053756  264.500000
#
# [2 rows x 30 columns]

# %%
X=new_file.drop(columns='Class',axis=1)

# %%
Y=new_file['Class']

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.2,stratify=Y,random_state=2)

# %%
model=LogisticRegression()

# %%
model.fit(X_train,Y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
X_train_prediction=model.predict(X_train)

# %%
training_data_acuracy=accuracy_score(X_train_prediction,Y_train)*100

# %%
print(f"Training Data Accuracy: {training_data_acuracy}%")
# Out:
# Training Data Accuracy: 100.0%

# %%
X_test_prediction=model.predict(X_test)

# %%
test_data_accuracy=accuracy_score(X_test_prediction,Y_test)*100

# %%
print(f"Test Data Accuracy: {test_data_accuracy}%")
# Out:
# Test Data Accuracy: 96.96969696969697%
